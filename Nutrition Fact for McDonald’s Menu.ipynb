# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('menu.csv')

# %% [markdown]
# ### 5 data pertama

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# ### Info data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
# Category                         260 non-null object
# Item                             260 non-null object
# Serving Size                     260 non-null object
# Calories                         260 non-null int64
# Calories from Fat                260 non-null int64
# Total Fat                        260 non-null float64
# Total Fat (% Daily Value)        260 non-null int64
# Saturated Fat                    260 non-null float64
# Saturated Fat (% Daily Value)    260 non-null int64
# Trans Fat                        260 non-null float64
# Cholesterol                      260 non-null int64
# Cholesterol (% Daily Value)      260 non-null int64
# Sodium                           260 non-null int64
# Sodium (% Daily Value)           260 non-null int64
# Carbohydrates                    260 non-null int64
# Carbohydrates (% Daily Value)    260 non-null int64
# ...

# %% [markdown]
# ### Cek Missing Value

# %%
print(df.isnull().any())
# Out:
# Category                         False
# Item                             False
# Serving Size                     False
# Calories                         False
# Calories from Fat                False
# Total Fat                        False
# Total Fat (% Daily Value)        False
# Saturated Fat                    False
# Saturated Fat (% Daily Value)    False
# Trans Fat                        False
# Cholesterol                      False
# Cholesterol (% Daily Value)      False
# Sodium                           False
# Sodium (% Daily Value)           False
# Carbohydrates                    False
# Carbohydrates (% Daily Value)    False
# Dietary Fiber                    False
# Dietary Fiber (% Daily Value)    False
# Sugars                           False
# Protein                          False
# Vitamin A (% Daily Value)        False
# Vitamin C (% Daily Value)        False
# Calcium (% Daily Value)          False
# Iron (% Daily Value)             False
# dtype: bool

# %% [markdown]
# ### Banyaknya Item disetiap Category

# %%
df.groupby('Category')['Item'].nunique()
# Out:
# Category
# Beef & Pork           15
# Beverages             27
# Breakfast             42
# Chicken & Fish        27
# Coffee & Tea          95
# Desserts               7
# Salads                 6
# Smoothies & Shakes    28
# Snacks & Sides        13
# Name: Item, dtype: int64

# %% [markdown]
# ### a) How many calories does the average McDonald's value meal contain?

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# ### Distribusi dari Calories

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution Calories")
cal_dist = sns.distplot(df["Calories"], color = 'b')

print(df.Calories.mean())
# Out:
# 368.2692307692308

# %% [markdown]
# ### b) How much do beverages, like soda or coffee, contribute to the overall caloric intake?

# %%
bev = np.array(df[df['Category']=='Beverages']['Item'].values).tolist()
bev
# Out:
# ['Coca-Cola Classic (Small)',
#  'Coca-Cola Classic (Medium)',
#  'Coca-Cola Classic (Large)',
#  'Coca-Cola Classic (Child)',
#  'Diet Coke (Small)',
#  'Diet Coke (Medium)',
#  'Diet Coke (Large)',
#  'Diet Coke (Child)',
#  'Dr Pepper (Small)',
#  'Dr Pepper (Medium)',
#  'Dr Pepper (Large)',
#  'Dr Pepper (Child)',
#  'Diet Dr Pepper (Small)',
#  'Diet Dr Pepper (Medium)',
#  'Diet Dr Pepper (Large)',
#  'Diet Dr Pepper (Child)',
#  'Sprite (Small)',
#  'Sprite (Medium)',
#  'Sprite (Large)',
#  'Sprite (Child)',
#  '1% Low Fat Milk Jug',
#  'Fat Free Chocolate Milk Jug',
#  'Minute Maid 100% Apple Juice Box',
#  'Minute Maid Orange Juice (Small)',
#  'Minute Maid Orange Juice (Medium)',
#  'Minute Maid Orange Juice (Large)',
#  'Dasani Water Bottle']

# %%
notsoda = ['1% Low Fat Milk Jug',
 'Fat Free Chocolate Milk Jug',
 'Minute Maid 100% Apple Juice Box',
 'Minute Maid Orange Juice (Small)',
 'Minute Maid Orange Juice (Medium)',
 'Minute Maid Orange Juice (Large)',
 'Dasani Water Bottle']
soda = [s for s in bev if s not in notsoda]
soda
# Out:
# ['Coca-Cola Classic (Small)',
#  'Coca-Cola Classic (Medium)',
#  'Coca-Cola Classic (Large)',
#  'Coca-Cola Classic (Child)',
#  'Diet Coke (Small)',
#  'Diet Coke (Medium)',
#  'Diet Coke (Large)',
#  'Diet Coke (Child)',
#  'Dr Pepper (Small)',
#  'Dr Pepper (Medium)',
#  'Dr Pepper (Large)',
#  'Dr Pepper (Child)',
#  'Diet Dr Pepper (Small)',
#  'Diet Dr Pepper (Medium)',
#  'Diet Dr Pepper (Large)',
#  'Diet Dr Pepper (Child)',
#  'Sprite (Small)',
#  'Sprite (Medium)',
#  'Sprite (Large)',
#  'Sprite (Child)']

# %%
df_soda = df[df['Item'].isin(soda)]
df_soda
# Out:
#       Category                        Item  Serving Size  Calories  \
# 110  Beverages   Coca-Cola Classic (Small)  16 fl oz cup       140
# 111  Beverages  Coca-Cola Classic (Medium)  21 fl oz cup       200
# 112  Beverages   Coca-Cola Classic (Large)  30 fl oz cup       280
# 113  Beverages   Coca-Cola Classic (Child)  12 fl oz cup       100
# 114  Beverages           Diet Coke (Small)  16 fl oz cup         0
# 115  Beverages          Diet Coke (Medium)  21 fl oz cup         0
# 116  Beverages           Diet Coke (Large)  30 fl oz cup         0
# 117  Beverages           Diet Coke (Child)  12 fl oz cup         0
# 118  Beverages           Dr Pepper (Small)  16 fl oz cup       140
# 119  Beverages          Dr Pepper (Medium)  21 fl oz cup       190
# 120  Beverages           Dr Pepper (Large)  30 fl oz cup       270
# 121  Beverages           Dr Pepper (Child)  12 fl oz cup       100
# 122  Beverages      Diet Dr Pepper (Small)  16 fl oz cup         0
# ...

# %%
df_soda[df_soda['Calories']==0]
# Out:
#       Category                     Item  Serving Size  Calories  \
# 114  Beverages        Diet Coke (Small)  16 fl oz cup         0
# 115  Beverages       Diet Coke (Medium)  21 fl oz cup         0
# 116  Beverages        Diet Coke (Large)  30 fl oz cup         0
# 117  Beverages        Diet Coke (Child)  12 fl oz cup         0
# 122  Beverages   Diet Dr Pepper (Small)  16 fl oz cup         0
# 123  Beverages  Diet Dr Pepper (Medium)  21 fl oz cup         0
# 124  Beverages   Diet Dr Pepper (Large)  30 fl oz cup         0
# 125  Beverages   Diet Dr Pepper (Child)  12 fl oz cup         0
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 114                  0        0.0                          0            0.0
# 115                  0        0.0                          0            0.0
# 116                  0        0.0                          0            0.0
# 117                  0        0.0                          0            0.0
# ...

# %%
df_sodam = df_soda.drop([114,115,116,117,122,123,124,125],axis=0)

# %%
persoda = (df_sodam['Calories'].sum()/df['Calories'].sum())*100
print('Persentase kalori yang disumbangkan soda : ',persoda,'%')
# Out:
# Persentase kalori yang disumbangkan soda :  2.234986945169713 %

# %%
cof = np.array(df[df['Category']=='Coffee & Tea']['Item'].values).tolist()

# %%
notcoffee = ['Iced Tea (Small)',
 'Iced Tea (Medium)',
 'Iced Tea (Large)',
 'Iced Tea (Child)',
 'Sweet Tea (Small)',
 'Sweet Tea (Medium)',
 'Sweet Tea (Large)',
 'Sweet Tea (Child)','Frappé Caramel (Small)',
 'Frappé Caramel (Medium)',
 'Frappé Caramel (Large)',
 'Frappé Chocolate Chip (Small)',
 'Frappé Chocolate Chip (Medium)',
 'Frappé Chocolate Chip (Large)','Hot Chocolate (Small)',
 'Hot Chocolate (Medium)',
 'Hot Chocolate (Large)',
 'Hot Chocolate with Nonfat Milk (Small)',
 'Hot Chocolate with Nonfat Milk (Medium)',
 'Hot Chocolate with Nonfat Milk (Large)',]
coffee = [c for c in cof if c not in notcoffee]

# %%
df_coffee = df[df['Item'].isin(coffee)]
df_coffee
# Out:
#          Category                                Item  Serving Size  Calories  \
# 145  Coffee & Tea                      Coffee (Small)  12 fl oz cup         0
# 146  Coffee & Tea                     Coffee (Medium)  16 fl oz cup         0
# 147  Coffee & Tea                      Coffee (Large)  16 fl oz cup         0
# 148  Coffee & Tea                       Latte (Small)  12 fl oz cup       170
# 149  Coffee & Tea                      Latte (Medium)  16 fl oz cup       210
# ..            ...                                 ...           ...       ...
# 221  Coffee & Tea  Iced Nonfat Caramel Mocha (Medium)  16 fl oz cup       270
# 222  Coffee & Tea   Iced Nonfat Caramel Mocha (Large)  22 fl oz cup       370
# 223  Coffee & Tea                Frappé Mocha (Small)  12 fl oz cup       450
# 224  Coffee & Tea               Frappé Mocha (Medium)  16 fl oz cup       550
# 225  Coffee & Tea                Frappé Mocha (Large)  22 fl oz cup       670
#
# ...

# %%
df_coffee[df_coffee['Calories']==0]
# Out:
#          Category             Item  Serving Size  Calories  Calories from Fat  \
# 145  Coffee & Tea   Coffee (Small)  12 fl oz cup         0                  0
# 146  Coffee & Tea  Coffee (Medium)  16 fl oz cup         0                  0
# 147  Coffee & Tea   Coffee (Large)  16 fl oz cup         0                  0
#
#      Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 145        0.0                          0            0.0
# 146        0.0                          0            0.0
# 147        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 145                              0        0.0  ...              0
# 146                              0        0.0  ...              0
# 147                              0        0.0  ...              0
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 145                              0              0
# ...

# %%
df_coffeem = df_coffee.drop([145,146,147],axis=0)

# %%
percoffee = (df_coffeem['Calories'].sum()/df['Calories'].sum())*100
print('Persentase kalori yang disumbangkan coffee : ',percoffee,'%')
# Out:
# Persentase kalori yang disumbangkan coffee :  21.263707571801564 %

# %% [markdown]
# ### Persentase kontribusi soda dan coffee terhadap asupan kalori harian

# %%
persoda1 = (df_sodam['Calories'].mean()/2000)*100
print('Persentase kontribusi soda terhadap asupan kalori harian : ',persoda1,'%')
# Out:
# Persentase kontribusi soda terhadap asupan kalori harian :  8.916666666666668 %

# %%
percoffee1 = (df_coffeem['Calories'].mean()/2000)*100
print('Persentase kontribusi coffee terhadap asupan kalori harian : ',percoffee1,'%')
# Out:
# Persentase kontribusi coffee terhadap asupan kalori harian :  14.13888888888889 %

# %% [markdown]
# ### Persentase kontribusi kalori harian per masing2 item Soda

# %%
df_soda1 = df_soda.set_index('Item')
calsoda = df_soda1['Calories']/20
calsoda.sort_values().plot(kind='barh',figsize=(10,6))

# %%
calsoda
# Out:
# Item
# Coca-Cola Classic (Small)      7.0
# Coca-Cola Classic (Medium)    10.0
# Coca-Cola Classic (Large)     14.0
# Coca-Cola Classic (Child)      5.0
# Diet Coke (Small)              0.0
# Diet Coke (Medium)             0.0
# Diet Coke (Large)              0.0
# Diet Coke (Child)              0.0
# Dr Pepper (Small)              7.0
# Dr Pepper (Medium)             9.5
# Dr Pepper (Large)             13.5
# Dr Pepper (Child)              5.0
# Diet Dr Pepper (Small)         0.0
# Diet Dr Pepper (Medium)        0.0
# Diet Dr Pepper (Large)         0.0
# Diet Dr Pepper (Child)         0.0
# Sprite (Small)                 7.0
# Sprite (Medium)               10.0
# Sprite (Large)                14.0
# Sprite (Child)                 5.0
# Name: Calories, dtype: float64

# %% [markdown]
# ### Persentase kontribusi kalori harian per masing2 item Coffee

# %%
df_coffee1 = df_coffee.set_index('Item')
calcoffee = df_coffee1['Calories']/20
calcoffee.sort_values().plot(kind='barh',figsize=(10,20))

# %%
calcoffee
# Out:
# Item
# Coffee (Small)                         0.0
# Coffee (Medium)                        0.0
# Coffee (Large)                         0.0
# Latte (Small)                          8.5
# Latte (Medium)                        10.5
#                                       ...
# Iced Nonfat Caramel Mocha (Medium)    13.5
# Iced Nonfat Caramel Mocha (Large)     18.5
# Frappé Mocha (Small)                  22.5
# Frappé Mocha (Medium)                 27.5
# Frappé Mocha (Large)                  33.5
# Name: Calories, Length: 75, dtype: float64

# %% [markdown]
# ### c) Does ordered grilled chicken instead of crispy increase a sandwich's nutritional value?

# %%
df[df['Category']=='Chicken & Fish']['Item'].values
# Out:
# array(['Premium Crispy Chicken Classic Sandwich',
#        'Premium Grilled Chicken Classic Sandwich',
#        'Premium Crispy Chicken Club Sandwich',
#        'Premium Grilled Chicken Club Sandwich',
#        'Premium Crispy Chicken Ranch BLT Sandwich',
#        'Premium Grilled Chicken Ranch BLT Sandwich',
#        'Bacon Clubhouse Crispy Chicken Sandwich',
#        'Bacon Clubhouse Grilled Chicken Sandwich',
#        'Southern Style Crispy Chicken Sandwich', 'McChicken',
#        'Bacon Cheddar McChicken', 'Bacon Buffalo Ranch McChicken',
#        'Buffalo Ranch McChicken',
#        'Premium McWrap Chicken & Bacon (Crispy Chicken)',
#        'Premium McWrap Chicken & Bacon (Grilled Chicken)',
#        'Premium McWrap Chicken & Ranch (Crispy Chicken)',
#        'Premium McWrap Chicken & Ranch (Grilled Chicken)',
#        'Premium McWrap Southwest Chicken (Crispy Chicken)',
#        'Premium McWrap Southwest Chicken (Grilled Chicken)',
# ...

# %%
sandwich = ['Premium Crispy Chicken Classic Sandwich',
       'Premium Grilled Chicken Classic Sandwich',
       'Premium Crispy Chicken Club Sandwich',
       'Premium Grilled Chicken Club Sandwich',
       'Premium Crispy Chicken Ranch BLT Sandwich',
       'Premium Grilled Chicken Ranch BLT Sandwich','Bacon Clubhouse Crispy Chicken Sandwich',
       'Bacon Clubhouse Grilled Chicken Sandwich']
df_sandwich = df[df['Item'].isin(sandwich)]
df_sandwich
# Out:
#           Category                                        Item  \
# 57  Chicken & Fish     Premium Crispy Chicken Classic Sandwich
# 58  Chicken & Fish    Premium Grilled Chicken Classic Sandwich
# 59  Chicken & Fish        Premium Crispy Chicken Club Sandwich
# 60  Chicken & Fish       Premium Grilled Chicken Club Sandwich
# 61  Chicken & Fish   Premium Crispy Chicken Ranch BLT Sandwich
# 62  Chicken & Fish  Premium Grilled Chicken Ranch BLT Sandwich
# 63  Chicken & Fish     Bacon Clubhouse Crispy Chicken Sandwich
# 64  Chicken & Fish    Bacon Clubhouse Grilled Chicken Sandwich
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 57  7.5 oz (213 g)       510                200       22.0
# 58    7 oz (200 g)       350                 80        9.0
# 59  8.8 oz (249 g)       670                300       33.0
# 60  8.3 oz (235 g)       510                180       20.0
# 61  8.1 oz (230 g)       610                250       28.0
# ...

# %%
header = df_sandwich['Item']
df_sandwich = df_sandwich.drop(['Category','Serving Size','Item'],axis=1)

# %%
for i in range(7):
  df_sandwich2 = df_sandwich[df_sandwich.columns[i*3:i*3+3]]
  df_sandwich_T=df_sandwich2.T
  df_sandwich_T.columns = header
  df_sandwich_T.plot(kind='bar',figsize=(10,6))

# %% [markdown]
# ### d) What about ordering egg whites instead of whole eggs?

# %%
df[df['Category']=='Breakfast']['Item'].values
# Out:
# array(['Egg McMuffin', 'Egg White Delight', 'Sausage McMuffin',
#        'Sausage McMuffin with Egg', 'Sausage McMuffin with Egg Whites',
#        'Steak & Egg McMuffin',
#        'Bacon, Egg & Cheese Biscuit (Regular Biscuit)',
#        'Bacon, Egg & Cheese Biscuit (Large Biscuit)',
#        'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)',
#        'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)',
#        'Sausage Biscuit (Regular Biscuit)',
#        'Sausage Biscuit (Large Biscuit)',
#        'Sausage Biscuit with Egg (Regular Biscuit)',
#        'Sausage Biscuit with Egg (Large Biscuit)',
#        'Sausage Biscuit with Egg Whites (Regular Biscuit)',
#        'Sausage Biscuit with Egg Whites (Large Biscuit)',
#        'Southern Style Chicken Biscuit (Regular Biscuit)',
#        'Southern Style Chicken Biscuit (Large Biscuit)',
#        'Steak & Egg Biscuit (Regular Biscuit)',
#        'Bacon, Egg & Cheese McGriddles',
# ...

# %%
egg = ['Sausage McMuffin with Egg', 'Sausage McMuffin with Egg Whites',
       'Sausage Biscuit with Egg (Regular Biscuit)',
       'Sausage Biscuit with Egg Whites (Regular Biscuit)',
       'Sausage Biscuit with Egg (Large Biscuit)',
       'Sausage Biscuit with Egg Whites (Large Biscuit)'
       ]
df_egg = df[df['Item'].isin(egg)]
df_egg
# Out:
#      Category                                               Item  \
# 3   Breakfast                          Sausage McMuffin with Egg
# 4   Breakfast                   Sausage McMuffin with Egg Whites
# 12  Breakfast         Sausage Biscuit with Egg (Regular Biscuit)
# 13  Breakfast           Sausage Biscuit with Egg (Large Biscuit)
# 14  Breakfast  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 15  Breakfast    Sausage Biscuit with Egg Whites (Large Biscuit)
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 3   5.7 oz (161 g)       450                250       28.0
# 4   5.7 oz (161 g)       400                210       23.0
# 12  5.7 oz (163 g)       510                290       33.0
# 13  6.2 oz (177 g)       570                330       37.0
# 14  5.9 oz (167 g)       460                250       27.0
# 15  6.4 oz (181 g)       520                280       32.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
header = df_egg['Item']
df_egg = df_egg.drop(['Category','Serving Size','Item'],axis=1)

# %%
for i in range(7):
  df_egg2 = df_egg[df_sandwich.columns[i*3:i*3+3]]
  df_egg_T=df_egg2.T
  df_egg_T.columns = header
  df_egg_T.plot(kind='bar',figsize=(10,6))

# %% [markdown]
# ### Menghilangkan 3 kolom pertama

# %%
df2 = df.drop(['Category', 'Item', 'Serving Size'], axis=1)
df2.head()
# Out:
#    Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 0       300                120       13.0                         20
# 1       250                 70        8.0                         12
# 2       370                200       23.0                         35
# 3       450                250       28.0                         43
# 4       400                210       23.0                         35
#
#    Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# 0            5.0                             25        0.0          260
# 1            3.0                             15        0.0           25
# 2            8.0                             42        0.0           45
# 3           10.0                             52        0.0          285
# 4            8.0                             42        0.0           50
#
#    Cholesterol (% Daily Value)  Sodium  ...  Carbohydrates  \
# ...

# %% [markdown]
# ### Visualisasi per Category

# %%
for i in df2.columns:
    df.pivot_table(i, 'Category').plot(kind='bar', stacked=True, color = 'r')
# Out:
# C:\Users\Deandra\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# ### e) What is the least number of items could you order from the menu to meet one day's nutritional requirements?
# Visualisasi per Item

# %%
def plot(grouped):
    item = grouped["Item"].sum()
    item_list = item.sort_index()
    item_list = item_list[-20:]
    plt.figure(figsize=(9,10))
    graph = sns.barplot(item_list.index,item_list.values)
    labels = [aj.get_text()[-40:] for aj in graph.get_yticklabels()]
    graph.set_yticklabels(labels)

for i in df2.columns:
    x = df.groupby(df[i])
    plot(x)
# Out:
# C:\Users\Deandra\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
